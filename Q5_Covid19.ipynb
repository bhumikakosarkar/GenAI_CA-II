# %%
import random

def generate_covid_data():
    data = []
    for _ in range(100):
        fever = round(random.uniform(97, 105), 1)
        cold = random.randint(1, 10)
        shivering = random.choice([True, False])
        weight_loss = round(random.uniform(0, 15), 1)
        data.append({
            "fever": fever,
            "cold": cold,
            "shivering": shivering,
            "weight_loss": weight_loss
        })
    return data

def sort_covid_data(data, param):
    if param == "shivering":
        return sorted(data, key=lambda x: x[param], reverse=False)
    else:
        return sorted(data, key=lambda x: x[param])

def main():
    data = generate_covid_data()
    print("Enter the parameter to sort by (fever, cold, shivering, weight_loss): ")
    param = input().strip()

    if param in ["fever", "cold", "shivering", "weight_loss"]:
        sorted_data = sort_covid_data(data, param)
        for record in sorted_data:
            print(record)
    else:
        print("Invalid parameter. Please enter 'fever', 'cold', 'shivering', or 'weight_loss'.")

if __name__ == "__main__":
    main()
# Out:
# Enter the parameter to sort by (fever, cold, shivering, weight_loss):
# cold
# {'fever': 101.9, 'cold': 1, 'shivering': False, 'weight_loss': 13.4}
# {'fever': 102.7, 'cold': 1, 'shivering': True, 'weight_loss': 4.6}
# {'fever': 99.6, 'cold': 1, 'shivering': True, 'weight_loss': 6.8}
# {'fever': 98.6, 'cold': 1, 'shivering': False, 'weight_loss': 6.2}
# {'fever': 103.5, 'cold': 1, 'shivering': False, 'weight_loss': 4.3}
# {'fever': 99.0, 'cold': 1, 'shivering': False, 'weight_loss': 13.9}
# {'fever': 102.3, 'cold': 1, 'shivering': True, 'weight_loss': 6.9}
# {'fever': 98.5, 'cold': 1, 'shivering': False, 'weight_loss': 13.9}
# {'fever': 101.4, 'cold': 1, 'shivering': False, 'weight_loss': 9.7}
# {'fever': 98.6, 'cold': 2, 'shivering': True, 'weight_loss': 3.7}
# {'fever': 97.5, 'cold': 2, 'shivering': True, 'weight_loss': 8.0}
# {'fever': 100.4, 'cold': 2, 'shivering': False, 'weight_loss': 10.5}
# {'fever': 101.1, 'cold': 2, 'shivering': True, 'weight_loss': 3.0}
# {'fever': 97.8, 'cold': 2, 'shivering': False, 'weight_loss': 10.9}
# {'fever': 99.2, 'cold': 2, 'shivering': False, 'weight_loss': 6.2}
# {'fever': 100.8, 'cold': 2, 'shivering': True, 'weight_loss': 6.7}
# {'fever': 104.0, 'cold': 2, 'shivering': False, 'weight_loss': 6.9}
# {'fever': 100.6, 'cold': 3, 'shivering': False, 'weight_loss': 5.6}
# {'fever': 99.4, 'cold': 3, 'shivering': True, 'weight_loss': 0.7}
# {'fever': 100.0, 'cold': 3, 'shivering': True, 'weight_loss': 6.9}
# {'fever': 104.5, 'cold': 3, 'shivering': True, 'weight_loss': 14.4}
# {'fever': 98.5, 'cold': 3, 'shivering': True, 'weight_loss': 13.9}
# {'fever': 100.0, 'cold': 3, 'shivering': False, 'weight_loss': 1.2}
# {'fever': 98.5, 'cold': 3, 'shivering': False, 'weight_loss': 13.8}
# {'fever': 102.8, 'cold': 3, 'shivering': True, 'weight_loss': 12.3}
# {'fever': 98.7, 'cold': 3, 'shivering': False, 'weight_loss': 0.8}
# {'fever': 102.6, 'cold': 3, 'shivering': False, 'weight_loss': 8.7}
# {'fever': 99.9, 'cold': 3, 'shivering': False, 'weight_loss': 2.6}
# {'fever': 104.3, 'cold': 4, 'shivering': False, 'weight_loss': 4.4}
# {'fever': 100.6, 'cold': 4, 'shivering': False, 'weight_loss': 5.8}
# {'fever': 98.5, 'cold': 4, 'shivering': False, 'weight_loss': 11.7}
# {'fever': 102.6, 'cold': 4, 'shivering': False, 'weight_loss': 13.8}
# {'fever': 101.9, 'cold': 4, 'shivering': False, 'weight_loss': 2.1}
# {'fever': 104.0, 'cold': 4, 'shivering': True, 'weight_loss': 3.4}
# {'fever': 103.2, 'cold': 4, 'shivering': True, 'weight_loss': 0.8}
# {'fever': 102.9, 'cold': 4, 'shivering': False, 'weight_loss': 11.5}
# {'fever': 99.9, 'cold': 4, 'shivering': True, 'weight_loss': 8.0}
# {'fever': 101.8, 'cold': 4, 'shivering': False, 'weight_loss': 13.3}
# {'fever': 98.4, 'cold': 5, 'shivering': True, 'weight_loss': 1.0}
# {'fever': 101.8, 'cold': 5, 'shivering': True, 'weight_loss': 1.5}
# {'fever': 102.7, 'cold': 5, 'shivering': True, 'weight_loss': 12.1}
# {'fever': 100.6, 'cold': 5, 'shivering': True, 'weight_loss': 1.7}
# {'fever': 104.3, 'cold': 5, 'shivering': False, 'weight_loss': 10.5}
# {'fever': 98.2, 'cold': 5, 'shivering': True, 'weight_loss': 5.3}
# {'fever': 102.5, 'cold': 5, 'shivering': True, 'weight_loss': 6.6}
# {'fever': 102.6, 'cold': 5, 'shivering': False, 'weight_loss': 9.1}
# {'fever': 98.1, 'cold': 5, 'shivering': False, 'weight_loss': 11.4}
# {'fever': 104.7, 'cold': 5, 'shivering': True, 'weight_loss': 10.1}
# {'fever': 103.8, 'cold': 6, 'shivering': False, 'weight_loss': 8.6}
# {'fever': 98.5, 'cold': 6, 'shivering': True, 'weight_loss': 14.5}
# {'fever': 103.2, 'cold': 6, 'shivering': False, 'weight_loss': 1.9}
# {'fever': 97.8, 'cold': 6, 'shivering': True, 'weight_loss': 11.7}
# {'fever': 97.3, 'cold': 6, 'shivering': False, 'weight_loss': 4.5}
# {'fever': 103.0, 'cold': 7, 'shivering': True, 'weight_loss': 6.6}
# {'fever': 100.7, 'cold': 7, 'shivering': True, 'weight_loss': 5.5}
# {'fever': 102.4, 'cold': 7, 'shivering': False, 'weight_loss': 0.4}
# {'fever': 103.3, 'cold': 7, 'shivering': False, 'weight_loss': 14.5}
# {'fever': 97.2, 'cold': 7, 'shivering': True, 'weight_loss': 3.5}
# {'fever': 99.0, 'cold': 7, 'shivering': True, 'weight_loss': 6.8}
# {'fever': 102.0, 'cold': 7, 'shivering': True, 'weight_loss': 14.4}
# {'fever': 98.5, 'cold': 7, 'shivering': False, 'weight_loss': 2.4}
# {'fever': 101.8, 'cold': 7, 'shivering': False, 'weight_loss': 12.0}
# {'fever': 103.3, 'cold': 7, 'shivering': False, 'weight_loss': 6.0}
# {'fever': 104.6, 'cold': 7, 'shivering': False, 'weight_loss': 12.9}
# {'fever': 101.1, 'cold': 7, 'shivering': False, 'weight_loss': 5.7}
# {'fever': 98.0, 'cold': 7, 'shivering': False, 'weight_loss': 4.8}
# {'fever': 102.1, 'cold': 7, 'shivering': False, 'weight_loss': 12.4}
# {'fever': 104.2, 'cold': 8, 'shivering': True, 'weight_loss': 14.9}
# {'fever': 97.1, 'cold': 8, 'shivering': True, 'weight_loss': 9.8}
# {'fever': 102.4, 'cold': 8, 'shivering': False, 'weight_loss': 14.0}
# {'fever': 101.4, 'cold': 8, 'shivering': True, 'weight_loss': 3.7}
# {'fever': 100.9, 'cold': 8, 'shivering': True, 'weight_loss': 1.8}
# {'fever': 97.6, 'cold': 8, 'shivering': False, 'weight_loss': 8.2}
# {'fever': 97.8, 'cold': 8, 'shivering': False, 'weight_loss': 12.8}
# {'fever': 98.7, 'cold': 8, 'shivering': True, 'weight_loss': 0.2}
# {'fever': 100.7, 'cold': 8, 'shivering': True, 'weight_loss': 0.8}
# {'fever': 101.4, 'cold': 8, 'shivering': False, 'weight_loss': 14.6}
# {'fever': 99.5, 'cold': 8, 'shivering': True, 'weight_loss': 9.0}
# {'fever': 98.8, 'cold': 8, 'shivering': True, 'weight_loss': 0.5}
# {'fever': 102.3, 'cold': 9, 'shivering': True, 'weight_loss': 0.9}
# {'fever': 103.7, 'cold': 9, 'shivering': True, 'weight_loss': 4.7}
# {'fever': 102.5, 'cold': 9, 'shivering': True, 'weight_loss': 13.5}
# {'fever': 99.9, 'cold': 9, 'shivering': True, 'weight_loss': 13.9}
# {'fever': 98.8, 'cold': 9, 'shivering': True, 'weight_loss': 14.1}
# {'fever': 102.5, 'cold': 9, 'shivering': False, 'weight_loss': 7.1}
# {'fever': 101.3, 'cold': 9, 'shivering': False, 'weight_loss': 1.2}
# {'fever': 101.8, 'cold': 9, 'shivering': True, 'weight_loss': 3.4}
# {'fever': 104.3, 'cold': 9, 'shivering': False, 'weight_loss': 10.8}
# {'fever': 104.9, 'cold': 9, 'shivering': False, 'weight_loss': 6.2}
# {'fever': 105.0, 'cold': 9, 'shivering': True, 'weight_loss': 10.9}
# {'fever': 102.4, 'cold': 9, 'shivering': False, 'weight_loss': 7.6}
# {'fever': 99.2, 'cold': 9, 'shivering': True, 'weight_loss': 9.1}
# {'fever': 97.9, 'cold': 10, 'shivering': True, 'weight_loss': 3.3}
# {'fever': 103.8, 'cold': 10, 'shivering': True, 'weight_loss': 15.0}
# {'fever': 103.6, 'cold': 10, 'shivering': False, 'weight_loss': 5.3}
# {'fever': 99.2, 'cold': 10, 'shivering': True, 'weight_loss': 5.6}
# {'fever': 101.2, 'cold': 10, 'shivering': True, 'weight_loss': 2.7}
# {'fever': 100.0, 'cold': 10, 'shivering': True, 'weight_loss': 2.0}
# {'fever': 100.4, 'cold': 10, 'shivering': True, 'weight_loss': 11.1}
# {'fever': 98.0, 'cold': 10, 'shivering': False, 'weight_loss': 9.1}
